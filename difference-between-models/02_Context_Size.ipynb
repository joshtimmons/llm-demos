# %% [markdown]
# <a href="https://colab.research.google.com/github/joshtimmons/llm-demos/blob/main/difference-between-models/02_Context_Size.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Context Size
#
# Context size is the number of tokens that a model can process at once. Small context sizes means that we can't provide too much information in our prompt and that we won't get a large amount of coherent output.
#
# This notebook starts with OpenLlama 2 7B, which has a 2K token context size. We'll generate a small number of tokens in our first pass then increase that on OpenLlama-2-7B and MPT-7B-Storywriter models.
#
#
# The 7B parameter models are significantly larger than the prior models and they requires at least 28GB of GPU ram to execute. That's because 7 billion * 2 bytes per floatint point parameter = 14 billion bytes. (Some models use 16 bit floats and some use 32 bit floats - and you can "quantize them" which means you can load them at lower precisions)
#
# You need an A100 to run this notebook. Change your runtime type in the menus above.

# %% [markdown]
# First we just need to install some libraries

# %%
# !pip install transformers sentence-transformers einops sentencepiece accelerate
# Out:
# Collecting transformers
#   Downloading transformers-4.34.0-py3-none-any.whl (7.7 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.7/7.7 MB 65.7 MB/s eta 0:00:00
# Collecting sentence-transformers
#   Downloading sentence-transformers-2.2.2.tar.gz (85 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 86.0/86.0 kB 11.5 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Collecting einops
#   Downloading einops-0.7.0-py3-none-any.whl (44 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 44.6/44.6 kB 5.5 MB/s eta 0:00:00
# Collecting sentencepiece
#   Downloading sentencepiece-0.1.99-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.3 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.3/1.3 MB 71.1 MB/s eta 0:00:00
# Collecting accelerate
#   Downloading accelerate-0.23.0-py3-none-any.whl (258 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 258.1/258.1 kB 28.1 MB/s eta 0:00:00
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from transformers) (3.12.4)
# Collecting huggingface-hub<1.0,>=0.16.4 (from transformers)
#   Downloading huggingface_hub-0.17.3-py3-none-any.whl (295 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 295.0/295.0 kB 33.0 MB/s eta 0:00:00
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.10/dist-packages (from transformers) (1.23.5)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from transformers) (23.1)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.10/dist-packages (from transformers) (6.0.1)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.10/dist-packages (from transformers) (2023.6.3)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from transformers) (2.31.0)
# Collecting tokenizers<0.15,>=0.14 (from transformers)
#   Downloading tokenizers-0.14.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (3.8 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.8/3.8 MB 87.4 MB/s eta 0:00:00
# Collecting safetensors>=0.3.1 (from transformers)
#   Downloading safetensors-0.3.3-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.3 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.3/1.3 MB 77.0 MB/s eta 0:00:00
# Requirement already satisfied: tqdm>=4.27 in /usr/local/lib/python3.10/dist-packages (from transformers) (4.66.1)
# Requirement already satisfied: torch>=1.6.0 in /usr/local/lib/python3.10/dist-packages (from sentence-transformers) (2.0.1+cu118)
# Requirement already satisfied: torchvision in /usr/local/lib/python3.10/dist-packages (from sentence-transformers) (0.15.2+cu118)
# Requirement already satisfied: scikit-learn in /usr/local/lib/python3.10/dist-packages (from sentence-transformers) (1.2.2)
# Requirement already satisfied: scipy in /usr/local/lib/python3.10/dist-packages (from sentence-transformers) (1.11.3)
# Requirement already satisfied: nltk in /usr/local/lib/python3.10/dist-packages (from sentence-transformers) (3.8.1)
# Requirement already satisfied: psutil in /usr/local/lib/python3.10/dist-packages (from accelerate) (5.9.5)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.10/dist-packages (from huggingface-hub<1.0,>=0.16.4->transformers) (2023.6.0)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub<1.0,>=0.16.4->transformers) (4.5.0)
# Collecting huggingface-hub<1.0,>=0.16.4 (from transformers)
#   Downloading huggingface_hub-0.16.4-py3-none-any.whl (268 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 268.8/268.8 kB 28.6 MB/s eta 0:00:00
# Requirement already satisfied: sympy in /usr/local/lib/python3.10/dist-packages (from torch>=1.6.0->sentence-transformers) (1.12)
# Requirement already satisfied: networkx in /usr/local/lib/python3.10/dist-packages (from torch>=1.6.0->sentence-transformers) (3.1)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from torch>=1.6.0->sentence-transformers) (3.1.2)
# Requirement already satisfied: triton==2.0.0 in /usr/local/lib/python3.10/dist-packages (from torch>=1.6.0->sentence-transformers) (2.0.0)
# Requirement already satisfied: cmake in /usr/local/lib/python3.10/dist-packages (from triton==2.0.0->torch>=1.6.0->sentence-transformers) (3.27.5)
# Requirement already satisfied: lit in /usr/local/lib/python3.10/dist-packages (from triton==2.0.0->torch>=1.6.0->sentence-transformers) (17.0.1)
# Requirement already satisfied: click in /usr/local/lib/python3.10/dist-packages (from nltk->sentence-transformers) (8.1.7)
# Requirement already satisfied: joblib in /usr/local/lib/python3.10/dist-packages (from nltk->sentence-transformers) (1.3.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests->transformers) (3.2.0)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->transformers) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->transformers) (2.0.5)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->transformers) (2023.7.22)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from scikit-learn->sentence-transformers) (3.2.0)
# Requirement already satisfied: pillow!=8.3.*,>=5.3.0 in /usr/local/lib/python3.10/dist-packages (from torchvision->sentence-transformers) (9.4.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2->torch>=1.6.0->sentence-transformers) (2.1.3)
# Requirement already satisfied: mpmath>=0.19 in /usr/local/lib/python3.10/dist-packages (from sympy->torch>=1.6.0->sentence-transformers) (1.3.0)
# Building wheels for collected packages: sentence-transformers
#   Building wheel for sentence-transformers (setup.py) ... done
#   Created wheel for sentence-transformers: filename=sentence_transformers-2.2.2-py3-none-any.whl size=125923 sha256=84855fa87183a5175e5eab9b9f1e7493ed9fe7fb141bf0af09a9e0f6cd2973f9
#   Stored in directory: /root/.cache/pip/wheels/62/f2/10/1e606fd5f02395388f74e7462910fe851042f97238cbbd902f
# Successfully built sentence-transformers
# Installing collected packages: sentencepiece, safetensors, einops, huggingface-hub, tokenizers, transformers, sentence-transformers, accelerate
# Successfully installed accelerate-0.23.0 einops-0.7.0 huggingface-hub-0.16.4 safetensors-0.3.3 sentence-transformers-2.2.2 sentencepiece-0.1.99 tokenizers-0.14.0 transformers-4.34.0

# %% [markdown]
# Our next attribute is context size. We continue with "It was a dark and stormy night." but we ramp up the number of output tokens and switch to a model with a very large context: MPT-7B.  Note that openllama and mpt are both running with the same number of parameters. The difference that we're emphasizing is context size.
#
# * Openllama 7b context: 4K
# * MPT 7b storywriter: 65K
#
# These are going to take longer to test because we have to download the 28GB models.

# %%
from transformers import pipeline
import torch
from transformers import AutoModelForCausalLM, AutoTokenizer
from transformers import GenerationConfig

# %%
prompt="It was a dark and stormy night. "

pipe = pipeline("text-generation", model="openlm-research/open_llama_7b_v2", device="cuda")

text = pipe(prompt)[0]["generated_text"]
print(text)
# Out:
# Downloading (…)lve/main/config.json:   0%|          | 0.00/502 [00:00<?, ?B/s]
# Downloading (…)model.bin.index.json:   0%|          | 0.00/26.8k [00:00<?, ?B/s]
# Downloading shards:   0%|          | 0/2 [00:00<?, ?it/s]
# Downloading (…)l-00001-of-00002.bin:   0%|          | 0.00/9.98G [00:00<?, ?B/s]
# Downloading (…)l-00002-of-00002.bin:   0%|          | 0.00/3.50G [00:00<?, ?B/s]
# Loading checkpoint shards:   0%|          | 0/2 [00:00<?, ?it/s]
# Downloading (…)neration_config.json:   0%|          | 0.00/132 [00:00<?, ?B/s]
# Downloading (…)okenizer_config.json:   0%|          | 0.00/593 [00:00<?, ?B/s]
# Downloading tokenizer.model:   0%|          | 0.00/512k [00:00<?, ?B/s]
# Downloading (…)cial_tokens_map.json:   0%|          | 0.00/330 [00:00<?, ?B/s]
# You are using the default legacy behaviour of the <class 'transformers.models.llama.tokenization_llama.LlamaTokenizer'>. This is expected, and simply means that the `legacy` (previous) behavior will be used so nothing changes for you. If you want to use the new behaviour, set `legacy=False`. This should only be set if you understand what it means, and thouroughly read the reason why this was added as explained in https://github.com/huggingface/transformers/pull/24565
# /usr/local/lib/python3.10/dist-packages/transformers/generation/utils.py:1260: UserWarning: Using the model-agnostic default `max_length` (=20) to control the generation length. We recommend setting `max_new_tokens` to control the maximum length of the generation.
#   warnings.warn(
# It was a dark and stormy night.
#
# # Chapter 1
#
# # The

# %% [markdown]
# To showcase the importance of context we're going to bump up the number of tokens that we ask the model to generate.
#
# # Important
# We're not going to have enough RAM to run these tests without restarting our notebook since these models are too load more than once in our 40GB of GPU ram.
#
# You can restart your notebook by going to "Runtime" and clicking "Restart Runtime" before you run the following cells.

# %%
from transformers import pipeline
import torch
from transformers import AutoModelForCausalLM, AutoTokenizer
from transformers import GenerationConfig
import textwrap

# %%
prompt="It was a dark and stormy night. "

pipe = pipeline("text-generation", model="openlm-research/open_llama_7b_v2", max_length=2000, device="cuda")

text = pipe(prompt)[0]["generated_text"]
wrapped_text = textwrap.fill(text, 65)
print(wrapped_text)
# Out:
# Loading checkpoint shards:   0%|          | 0/2 [00:00<?, ?it/s]
# You are using the default legacy behaviour of the <class 'transformers.models.llama.tokenization_llama.LlamaTokenizer'>. This is expected, and simply means that the `legacy` (previous) behavior will be used so nothing changes for you. If you want to use the new behaviour, set `legacy=False`. This should only be set if you understand what it means, and thouroughly read the reason why this was added as explained in https://github.com/huggingface/transformers/pull/24565
# It was a dark and stormy night.   # Chapter 1  # The Dark and
# Stormy Night  It was a dark and stormy night.  The rain fell in
# torrents—except at occasional intervals, when it was checked by a
# violent gust of wind which swept up the streets (for it is in
# London that our scene lies) in great drifts of mud.  The lighted
# window of a large house was for a long time visible through a
# driving squall of rain.  The rain fell in torrents—except at
# occasional intervals, when it was checked by a violent gust of
# wind which swept up the streets (for it is in London that our
# scene lies) in great drifts of mud.  The lighted window of a
# large house was for a long time visible through a driving squall
# of rain.  The rain fell in torrents—except at occasional
# intervals, when it was checked by a violent gust of wind which
# swept up the streets (for it is in London that our scene lies) in
# great drifts of mud.  The lighted window of a large house was for
# a long time visible through a driving squall of rain.  The rain
# fell in torrents—except at occasional intervals, when it was
# checked by a violent gust of wind which swept up the streets (for
# it is in London that our scene lies) in great drifts of mud.  The
# lighted window of a large house was for a long time visible
# through a driving squall of rain.  The rain fell in
# torrents—except at occasional intervals, when it was checked by a
# violent gust of wind which swept up the streets (for it is in
# London that our scene lies) in great drifts of mud.  The lighted
# window of a large house was for a long time visible through a
# driving squall of rain.  The rain fell in torrents—except at
# occasional intervals, when it was checked by a violent gust of
# wind which swept up the streets (for it is in London that our
# scene lies) in great drifts of mud.  The lighted window of a
# large house was for a long time visible through a driving squall
# of rain.  The rain fell in torrents—except at occasional
# intervals, when it was checked by a violent gust of wind which
# swept up the streets (for it is in London that our scene lies) in
# great drifts of mud.  The lighted window of a large house was for
# a long time visible through a driving squall of rain.  The rain
# fell in torrents—except at occasional intervals, when it was
# checked by a violent gust of wind which swept up the streets (for
# it is in London that our scene lies) in great drifts of mud.  The
# lighted window of a large house was for a long time visible
# through a driving squall of rain.  The rain fell in
# torrents—except at occasional intervals, when it was checked by a
# violent gust of wind which swept up the streets (for it is in
# London that our scene lies) in great drifts of mud.  The lighted
# window of a large house was for a long time visible through a
# driving squall of rain.  The rain fell in torrents—except at
# occasional intervals, when it was checked by a violent gust of
# wind which swept up the streets (for it is in London that our
# scene lies) in great drifts of mud.  The lighted window of a
# large house was for a long time visible through a driving squall
# of rain.  The rain fell in torrents—except at occasional
# intervals, when it was checked by a violent gust of wind which
# swept up the streets (for it is in London that our scene lies) in
# great drifts of mud.  The lighted window of a large house was for
# a long time visible through a driving squall of rain.  The rain
# fell in torrents—except at occasional intervals, when it was
# checked by a violent gust of wind which swept up the streets (for
# it is in London that our scene lies) in great drifts of mud.  The
# lighted window of a large house was for a long time visible
# through a driving squall of rain.  The rain fell in
# torrents—except at occasional intervals, when it was checked by a
# violent gust of wind which swept up the streets (for it is in
# London that our scene lies) in great drifts of mud.  The lighted
# window of a large house was for a long time visible through a
# driving squall of rain.  The rain fell in torrents—except at
# occasional intervals, when it was checked by a violent gust of
# wind which swept up the streets (for it is in London that our
# scene lies) in great drifts of mud.  The lighted window of a
# large house was for a long time visible through a driving squall
# of rain.  The rain fell in torrents—except at occasional
# intervals, when it was checked by a violent gust of wind which
# swept up the streets (for it is in London that our scene lies) in
# great drifts of mud.  The lighted window of a large house was for
# a long time visible through a driving squall of rain.  The rain
# fell in torrents—except at occasional intervals, when it was
# checked by a violent gust of wind which swept up the streets (for
# it is in London that our scene lies) in great drifts of mud.  The
# lighted window of a large house was for a long time visible
# through a driving squall of rain.  The rain fell in
# torrents—except at occasional intervals, when it was checked by a
# violent gust of wind which swept up the streets (for it is in
# London that our scene lies) in great drifts of mud.  The lighted
# window of a large house was for a long time visible through a
# driving squall of rain.  The rain fell in torrents—except at
# occasional intervals, when it was checked by a violent gust of
# wind which swept up the streets (for it is in London that our
# scene lies) in great drifts of mud.  The lighted window of a
# large house was for a long time visible through a driving squall
# of rain.  The rain fell in torrents—except at occasional
# intervals, when it was checked by a violent gust of wind which
# swept up the streets (for it is in London that our scene lies) in
# great drifts of mud.  The lighted window of a large house was for
# a long time visible through a driving squall of rain.  The rain
# fell in torrents—except at occasional intervals, when it was
# checked by a violent gust of wind which swept up the streets (for
# it is in London that our scene lies) in great drifts of mud.  The
# lighted window of a large house was for a long time visible
# through a driving squall of rain.  The rain fell in
# torrents—except at occasional intervals, when it was checked by a
# violent gust of wind which swept up the streets (for it is in
# London that our scene lies) in great drifts of mud.  The lighted
# window of a large house was for a long time visible through a
# driving squall of rain.  The rain fell in torrents—except at
# occasional intervals, when it was checked by a violent gust of
# wind which swept up the streets (for it is in London that our
# scene lies) in great drifts of mud.  The lighted window of a
# large house was for a long time visible through a driving squall
# of rain.  The rain fell in torrents—except at occasional
# intervals, when it was checked by a violent gust of wind which
# swept up the streets (for it is in London that our scene lies) in
# great drifts of mud.  The lighted window of a large house was for
# a long time visible through a driving squall of rain.  The rain
# fell in torrents—except at occasional intervals, when it was
# checked by a violent gust of wind which swept up the streets (for
# it is in London that our scene lies) in great drifts of mud.  The
# lighted window of a large house was for a long time visible
# through a driving squall of rain.  The rain fell in
# torrents—except at occasional intervals, when it was checked by a
# violent gust of wind which swept up the streets (for it is in
# London that our scene lies) in great drifts of mud.  The lighted
# window of a large house was for a long time visible through a
# driving squall of rain.  The rain fell in torrents—except at
# occasional intervals, when it was checked by a violent gust of
# wind which swept up the streets (for it is in London that our
# scene lies) in great drifts of mud.  The lighted window of a
# large house was for a long time visible through a driving squall
# of rain.  The rain fell in torrents—except at occasional
# intervals, when it was checked by a violent gust of wind which
# swept up the streets (for it is in London that our scene lies) in
# great drifts of mud.  The lighted window of a large house was for
# a long time visible through a driving squall of rain.  The rain
# fell in torrents—except at occasional intervals, when it was
# checked by a

# %% [markdown]
# Our next model is the MPT storyteller. It has an amazing 65K token context. This means that your combined input and output can be 65K tokens.
#
# # Important
# Don't forget to  restart your notebook by going to "Runtime" and clicking "Restart Runtime" before you run the following cells.

# %%
from transformers import pipeline
import torch
from transformers import AutoModelForCausalLM, AutoTokenizer
from transformers import GenerationConfig
import textwrap

# %%
model = None
pipe = None
tokenizer = None

torch.cuda.empty_cache()

# %%
model_name = "ethzanalytics/mpt-7b-storywriter-sharded"
prompt = "It was a dark and stormy night."
max_new_tokens = 2000

model = AutoModelForCausalLM.from_pretrained(
    model_name,
    torch_dtype=torch.bfloat16,
    trust_remote_code=True,
    revision='b51ddaf1a256420debfb44fd7367ed7b291b7c19',
    device_map='auto',
    load_in_8bit=False, # install bitsandbytes and then set to true for 8-bit
)
model = torch.compile(model)
tokenizer = AutoTokenizer.from_pretrained(model_name)

model.generation_config = GenerationConfig.from_pretrained(model_name)

def get_token_count(text:str):
    return len(tokenizer.encode(text, truncation=False, padding=False))


torch.cuda.empty_cache()
inputs = tokenizer(prompt, return_tensors="pt").to(
    model.device
)
input_length = inputs.input_ids.shape[1]

outputs = model.generate(
    **inputs,
    return_dict_in_generate=True,
    generation_config=model.generation_config,
    max_new_tokens=max_new_tokens
)
token = outputs.sequences[0, input_length:]
result = tokenizer.decode(
    token, skip_special_tokens=True, clean_up_tokenization_spaces=True
)

wrapped_text = textwrap.fill(result, 65)
print(wrapped_text)
# Out:
# Downloading (…)291b7c19/config.json:   0%|          | 0.00/1.28k [00:00<?, ?B/s]
# Downloading (…)configuration_mpt.py:   0%|          | 0.00/9.87k [00:00<?, ?B/s]
# Downloading (…)7c19/modeling_mpt.py:   0%|          | 0.00/20.1k [00:00<?, ?B/s]
# Downloading (…)ed7b291b7c19/norm.py:   0%|          | 0.00/3.06k [00:00<?, ?B/s]
# Downloading (…)9/adapt_tokenizer.py:   0%|          | 0.00/1.76k [00:00<?, ?B/s]
# Downloading (…)19/param_init_fns.py:   0%|          | 0.00/14.3k [00:00<?, ?B/s]
# Downloading (…)91b7c19/attention.py:   0%|          | 0.00/18.1k [00:00<?, ?B/s]
# Downloading (…)refixlm_converter.py:   0%|          | 0.00/31.4k [00:00<?, ?B/s]
# Downloading (…)7b291b7c19/blocks.py:   0%|          | 0.00/2.99k [00:00<?, ?B/s]
# Downloading (…)meta_init_context.py:   0%|          | 0.00/3.81k [00:00<?, ?B/s]
# Downloading (…)model.bin.index.json:   0%|          | 0.00/16.0k [00:00<?, ?B/s]
# Downloading shards:   0%|          | 0/7 [00:00<?, ?it/s]
# Downloading (…)l-00001-of-00007.bin:   0%|          | 0.00/1.89G [00:00<?, ?B/s]
# Downloading (…)l-00002-of-00007.bin:   0%|          | 0.00/1.88G [00:00<?, ?B/s]
# Downloading (…)l-00003-of-00007.bin:   0%|          | 0.00/1.98G [00:00<?, ?B/s]
# Downloading (…)l-00004-of-00007.bin:   0%|          | 0.00/1.91G [00:00<?, ?B/s]
# Downloading (…)l-00005-of-00007.bin:   0%|          | 0.00/1.88G [00:00<?, ?B/s]
# Downloading (…)l-00006-of-00007.bin:   0%|          | 0.00/1.88G [00:00<?, ?B/s]
# Downloading (…)l-00007-of-00007.bin:   0%|          | 0.00/1.88G [00:00<?, ?B/s]
# /root/.cache/huggingface/modules/transformers_modules/ethzanalytics/mpt-7b-storywriter-sharded/b51ddaf1a256420debfb44fd7367ed7b291b7c19/attention.py:269: UserWarning: Using `attn_impl: torch`. If your model does not use `alibi` or `prefix_lm` we recommend using `attn_impl: flash` otherwise we recommend using `attn_impl: triton`.
#   warnings.warn(
# WARNING:accelerate.utils.modeling:The model weights are not tied. Please use the `tie_weights` method before using the `infer_auto_device` function.
# Loading checkpoint shards:   0%|          | 0/7 [00:00<?, ?it/s]
# Downloading (…)neration_config.json:   0%|          | 0.00/265 [00:00<?, ?B/s]
# Downloading (…)okenizer_config.json:   0%|          | 0.00/264 [00:00<?, ?B/s]
# Downloading (…)/main/tokenizer.json:   0%|          | 0.00/2.11M [00:00<?, ?B/s]
# Downloading (…)cial_tokens_map.json:   0%|          | 0.00/99.0 [00:00<?, ?B/s]
#  The wind howled, rain poured down in sheets.  And the lights
# went out. Chapter 3  The first few days of school are always an
# adjustment for everyone involved: teachers, students—and parents.
# But it's particularly hard when the new student is you,
# especially if that new kid has just been released from prison
# after serving time for murdering his girlfriend. And especially
# hard if that new kid happens to be your own daughter.  "You know
# what they say about lightning never striking twice," my mother
# said on the phone as I sat on my bed trying to decide whether or
# not I should wear a pair of jeans with holes in them under my
# uniform skirt. It wasn't like she didn't have better things to
# talk about than me. She could tell me her life story from start
# to finish without ever running out of material. "Well, I'm here
# to set the record straight."  I sighed. "Mom, I'm not the
# lightning."  "But it did strike once."  My father died three
# years ago. My brother died two years earlier. My sister died one
# year before. So far this fall season had been a bit of a bummer
# for my family tree, but at least none of them were murdered by a
# former classmate whose name was also my name.  "So?" I asked,
# still staring at the hole-ridden jeans. I couldn't see any reason
# why wearing them would make things worse.  "What if something
# happened to you? You're so much younger than I am! What would
# become of me then?"  I stared at her through the receiver of the
# phone. "Something will probably happen to all of us eventually.
# We don't have a choice. We can only hope we die well."  She
# laughed. "That's what I thought too until last week. Now I'm
# afraid of everything!"  "Don't worry, Mom." My mother was prone
# to exaggeration. "If there's anything I learned while I was
# locked up, it's that nothing good ever comes of worrying.
# Besides, I'm not exactly a danger to society anymore."  She
# sniffed into the receiver. "You've changed since you came out of
# there. You're moodier now. And you don't even try to hide it
# either."  I shrugged, which was pretty easy to do because my arms
# She nodded again.  I breathed deeply in and out. "Mrs. Bauer, you
# really did call me Mike?"  Her head bobbed up and down. "I did."
# My eyes shifted back and forth between hers. "You called me
# Mike."  Her head continued to nod. "I certainly did."  I closed
# my eyes tightly again. "Mike?"  "Yes, Michael," she answered,
# smiling.  I opened my eyes. "Mike?"  She repeated herself. "Yes,
# Mike." Chapter 4  The rest of that day was spent walking through
# memories like ghosts haunting the corridors and hallways of St.
# Mary Academy High School.  I passed Mr. Foley, the janitor who
# had caught me smoking cigarettes in the girls bathroom. I
# remembered him telling me I smelled bad and that he hoped I
# didn't have any diseases.  In English, Ms. Larkin told me that
# I'd missed a lot of work while I was gone. She reminded me that
# she was giving me extra credit to make up for it.  In history,
# Mr. Kincaid told me about the war. He explained how many people
# died during World War II. I asked him why so many people died. He
# said they were killed because they believed in different things.
# I told him I understood that part, but why did people fight over
# such stupid reasons like religion and money? He said it was
# because they didn't understand each other.  I passed Mrs.
# Osterberg, who was teaching math. She asked me if I was doing
# fine in her class. I told her that I was fine. She asked me if I
# was having fun in high school. I told her I was enjoying it very
# much.  In gym, Coach McGuire told me that I hadn't lost my form
# in the past five years. He said he expected me to win the
# championship this coming spring.  In art, Mr. Garrison told me
# that I was a great artist but I had no talent. I told him I
# didn't agree with that assessment. He told me that I had no
# imagination whatsoever.  In chemistry, Mrs. Sweeney told me that
# I had a strong sense of smell but I was missing some important

# %%
from transformers import pipeline
import torch
from transformers import AutoModelForCausalLM, AutoTokenizer
from transformers import GenerationConfig
import textwrap

# %%
model = None
pipe = None
tokenizer = None

torch.cuda.empty_cache()

# %%
# Use a pipeline as a high-level helper
from transformers import pipeline

pipe = pipeline("text-generation", model="meta-llama/Llama-2-7b-chat-hf", device="cuda")
# Out:
# Loading checkpoint shards:   0%|          | 0/2 [00:00<?, ?it/s]

# %% [markdown]
# Here we're talking about the difference between base models, and models tuned for conversational or tasks.
#
# The demo here includes a few prompts against Llama 2 in chat vs base mode.

# %%
prompt = "How are you doing today?"
text = pipe(prompt)[0]["generated_text"]
print(f"\n\n{prompt}\n{text}")

prompt = "It was a dark and stormy night. "
text = pipe(prompt)[0]["generated_text"]
print(f"\n\n{prompt}\n{text}")

prompt = "Please list 5 uses for a pencil"
text = pipe(prompt)[0]["generated_text"]
print(f"\n\n{prompt}\n{text}")
# Out:
# How are you doing today?
# How are you doing today?
#
# I hope you are doing well.
#
# You are very important to me.
#
# I am so glad you are my friend.
#
# You make me so happy.
#
# I love you so much.
#
# I am so grateful for you.
#
# You are the best friend ever.
#
# I will always be there for you.
#
# You are my everything.
#
# I love you more than words can say.
#
# You are the best thing that ever happened to me.
#
# I am so lucky to have you in my life.
#
# You are my soulmate.
#
# I will never let you go.
#
# You are my everything.
#
# I love you more than life itself.
#
# You are my forever friend.
#
# I will always cherish and love you.
#
# You are the best thing that has ever happened to me.
#
# I am so grateful for our friendship.
#
# You are my everything.
#
# I love you more than anything.
#
# You are my soulmate.
#
# I will never let you go.
#
# You are my forever friend.
#
# I will always cherish and love you.
#
# You are the best thing that has ever happened to me.
#
# I am so lucky to have you in my life.
#
# You are my everything.
#
# I love you more than life itself.
#
# You are my forever friend.
#
# I will always cherish and love you.
#
# You are the best thing that has ever happened to me.
#
# I am so grateful for our friendship.
#
# You are my everything.
#
# I love you more than anything.
#
# You are my soulmate.
#
# I will never let you go.
#
# You are my forever friend.
#
# I will always cherish and love you.
#
# You are the best thing that has ever happened to me.
#
# I am so lucky to have you in my life.
#
# You are my everything.
#
# I love you more than life itself.
#
# You are my forever friend.
#
# I will always cherish and love you.
#
# You are the best thing that has ever happened to me.
#
# I am so grateful for our friendship.
#
# You are my everything.
#
# I love you more than anything.
#
# You are my soulmate.
#
# I will never let you go.
#
# You are my forever friend.
#
# I will always cherish and love you.
#
# You are the best thing that has ever happened to me.
#
# I am so lucky to have you in my life.
#
# You are my everything.
#
# I love you more than life itself.
#
# You are my forever friend.
#
# I will always cherish and love you.
#
# You are the best thing that has ever happened to me.
#
# I am so grateful for our friendship.
#
# You are my everything.
#
# I love you more than anything.
#
# You are my soulmate.
#
# I will never let you go.
#
# You are my forever friend.
#
# I will always cherish and love you.
#
# You are the best thing that has ever happened to me.
#
# I am so lucky to have you in my life.
#
# You are my everything.
#
# I love you more than life itself.
#
# You are my forever friend.
#
# I will always cherish and love you.
#
# You are the best thing that has ever happened to me.
#
# I am so grateful for our friendship.
#
# You are my everything.
#
# I love you more than anything.
#
# You are my soulmate.
#
# I will never let you go.
#
# You are my forever friend.
#
# I will always cherish and love you.
#
# You are the best thing that has ever happened to me.
#
# I am so lucky to have you in my life.
#
# You are my everything.
#
# I love you more than life itself.
#
# You are my forever friend.
#
# I will always cherish and love you.
#
# You are the best thing that has ever happened to me.
#
# I am so grateful for our friendship.
#
# You are my everything.
#
# I love you more than anything.
#
# You are my soulmate.
#
# I will never let you go.
#
# You are my forever friend.
#
# I will always cherish and love you.
#
# You are the best thing that has ever happened to me.
#
# I am so lucky to have you in my life.
#
# You are my everything.
#
# I love you more than life itself.
#
# You are my forever friend.
#
# I will always cherish and love you.
#
# You are the best thing that has ever happened to me.
#
# I am so grateful for our friendship.
#
# You are my everything.
#
# I love you more than anything.
#
# You are my soulmate.
#
# I will never let you go.
#
# You are my forever friend.
#
# I will always cherish and love you.
#
# You are the best thing that has ever happened to me.
#
# I am so lucky to have you in my life.
#
# You are my everything.
#
# I love you more than life itself.
#
# You are my forever friend.
#
# I will always cherish and love you.
#
# You are the best thing that has ever happened to me.
#
# I am so grateful for our friendship.
#
# You are my everything.
#
# I love you more than anything.
#
# You are my soulmate.
#
# I will never let you go.
#
# You are my forever friend.
#
# I will always cherish and love you.
#
# You are the best thing that has ever happened to me.
#
# I am so lucky to have you in my life.
#
# You are my everything.
#
# I love you more than life itself.
#
# You are my forever friend.
#
# I will always cherish and love you.
#
# You are the best thing that has ever happened to me.
#
# I am so grateful for our friendship.
#
# You are my everything.
#
# I love you more than anything.
#
# You are my soulmate.
#
# I will never let you go.
#
# You are my forever friend.
#
# I will always cherish and love you.
#
# You are the best thing that has ever happened to me.
#
# I am so lucky to have you in my life.
#
# You are my everything.
#
# I love you more than life itself.
#
# You are my forever friend.
#
# I will always cherish and love you.
#
# You are the best thing that has ever happened to me.
#
# I am so grateful for our friendship.
#
# You are my everything.
#
# I love you more than anything.
#
# You are my soulmate.
#
# I will never let you go.
#
# You are my forever friend.
#
# I will always cherish and love you.
#
# You are the best thing that has ever happened to me.
#
# I am so lucky to have you in my life.
#
# You are my everything.
#
# I love you more than life itself.
#
# You are my forever friend.
#
# I will always cherish and love you.
#
# You are the best thing that has ever happened to me.
#
# I am so grateful for our friendship.
#
# You are my everything.
#
# I love you more than anything.
#
# You are my soulmate.
#
# I will never let you go.
#
# You are my forever friend.
#
# I will always cherish and love you.
#
# You are the best thing that has ever happened to me.
#
# I am so lucky to have you in my life.
#
# You are my everything.
#
# I love you more than life itself.
#
# You are my forever friend.
#
# I will always cherish and love you.
#
# You are the best thing that has ever happened to me.
#
# I am so grateful for our friendship.
#
# You are my everything.
#
# I love you more than anything.
#
# You are my soulmate.
#
# I will never let you go.
#
# You are my forever friend.
#
# I will always cherish and love you.
#
# You are the best thing that has ever happened to me.
#
# I am so lucky to have you in my life.
#
# You are my everything.
#
# I love you more than life itself.
#
# You are my forever friend.
#
# I will always cherish and love you.
#
# You are the best thing that has ever happened to me.
#
# I am so grateful for our friendship.
#
# You are my everything.
#
# I love you more than anything.
#
# You are my soulmate.
#
# I will never let you go.
#
# You are my forever friend.
#
# I will always cherish and love you.
#
# You are the best thing that has ever happened to me.
#
# I am so lucky to have you in my life.
#
# You are my everything.
#
# I love you more than life itself.
#
# You are my forever friend.
#
# I will always cherish and love you.
#
# You are the best thing that has ever happened to me.
#
# I am so grateful for our friendship.
#
# You are my everything.
#
# I love you more than anything.
#
# You are my soulmate.
#
# I will never let you go.
#
# You are my forever friend.
#
# I will always cherish and love you.
#
# You are the best thing that has ever happened to me.
#
# I am so lucky to have you in my life.
#
# You are my everything.
#
# I love you more than life itself.
#
# You are my forever friend.
#
# I will always cherish and love you.
#
# You are the best thing that has ever happened to me.
#
# I am so grateful for our friendship.
#
# You are my everything.
#
# I love you more than anything.
#
# You are my soulmate.
#
# I will never let you go.
#
# You are my forever friend.
#
# I will always cherish and love you.
#
# You are the best thing that has ever happened to me.
#
# I am so lucky to have you in my life.
#
# You are my everything.
#
# I love you more than life itself.
#
# You are my forever friend.
#
# I will always cherish and love you.
#
# You are the best thing that has ever happened to me.
#
# I am so grateful for our friendship.
#
# You are my everything.
#
# I love you more than anything.
#
# You are my soulmate.
#
# I will never let you go.
#
# You are my forever friend.
#
# I will always cherish and love you.
#
# You are the best thing that has ever happened to me.
#
# I am so lucky to have you in my life.
#
# You are my everything.
#
# I love you more than life itself.
#
# You are my forever friend.
#
# I will always cherish and love you.
#
# You are the best thing that has ever happened to me.
#
# I am so grateful for our friendship.
#
# You are my everything.
#
# I love you more than anything.
#
# You are my soulmate.
#
# I will never let you go.
#
# You are my forever friend.
#
# I will always cherish and love you.
#
# You are the best thing that has ever happened to me.
#
# I am so lucky to have you in my life.
#
# You are my everything.
#
# I love you more than life itself.
#
# You are my forever friend.
#
# I will always cherish and love you.
#
# You are the best thing that has ever happened to me.
#
# I am so grateful for our friendship.
#
# You are my everything.
#
# I love you more than anything.
#
# You are my soulmate.
#
# I will never let you go.
#
# You are my forever friend.
#
# I will always cherish and love you.
#
# You are the best thing that has ever happened to me.
#
# I am so lucky to have you in my life.
#
# You are my everything.
#
# I love you more than life itself.
#
# You are my forever friend.
#
# I will always cherish and love you.
#
# You are the best thing that has ever happened to me.
#
# I am so grateful for our friendship.
#
# You are my everything.
#
# I love you more than anything.
#
# You are my soulmate.
#
# I will never let you go.
#
# You are my forever friend.
#
# I will always cherish and love you.
#
# You are the best thing that has ever happened to me.
#
# I am so lucky to have you in my life.
#
# You are my everything.
#
# I love you more than life itself.
#
# You are my forever friend.
#
# I will always cherish and love you.
#
# You are the best thing that has ever happened to me.
#
# I am so grateful for our friendship.
#
# You are my everything.
#
# I love you more than anything.
#
# You are my soulmate.
#
# I will never let you go.
#
# You are my forever friend.
#
# I will always cherish and love you.
#
# You are the best thing that has ever happened to me.
#
# I am so lucky to have you in my life.
#
# You are my everything.
#
# I love you more than life itself.
#
# You are my forever friend.
#
# I will always cherish and love you.
#
# You are the best thing that has ever happened to me.
#
# I am so grateful for our friendship.
#
# You are my everything.
#
# I love you more than anything.
#
# You are my soulmate.
#
# I will never let you go.
#
# You are my forever friend.
#
# I will always cherish and love you.
#
# You are the best thing that has ever happened to me.
#
# I am so lucky to have you in my life.
#
# You are my everything.
#
# I love you more than life itself.
#
# You are my forever friend.
#
# I will always cherish and love you.
#
# You are the best thing that has ever happened to me.
#
# I am so grateful for our friendship.
#
# You are my everything.
#
# I love you more than anything.
#
# You are my soulmate.
#
# I will never let you go.
#
# You are my forever friend.
#
# I will always cherish and love you.
#
# You are the best thing that has ever happened to me.
#
# I am so lucky to have you in my life.
#
# You are my everything.
#
# I love you more than life itself.
#
# You are my forever friend.
#
# I will always cherish and love you.
#
# You are the best thing that has ever happened to me.
#
# I am so grateful for our friendship.
#
# You are my everything.
#
# I love you more than anything.
#
# You are my soulmate.
#
# I will never let you go.
#
# You are my forever friend.
#
# I will always cherish and love you.
#
# You are the best thing that has ever happened to me.
#
# I am so lucky to have you in my life.
#
# You are my everything.
#
# I love you more than life itself.
#
# You are my forever friend.
#
# I will always cherish and love you.
#
# You are the best thing that has ever happened to me.
#
# I am so grateful for our friendship.
#
# You are my everything.
#
# I love you more than anything.
#
# You are my soulmate.
#
# I will never let you go.
#
# You are my forever friend.
#
# I will always cherish and love you.
#
# You are the best thing that has ever happened to me.
#
# I am so lucky to have you in my life.
#
# You are my everything.
#
# I love you more than life itself.
#
# You are my forever friend.
#
# I will always cherish and love you.
#
# You are the best thing that has ever happened to me.
#
# I am so grateful for our friendship.
#
# You are my everything.
#
# I love you more than anything.
#
# You are my soulmate.
#
# I will never let you go.
#
# You are my forever friend.
#
# I will always cherish and love you.
#
# You are the best thing that has ever happened to me.
#
# I am so lucky to have you in my life.
#
# You are my everything.
#
# I love you more than life itself.
#
# You are my forever friend.
#
# I will always cherish and love you.
#
# You are the best thing that has ever happened to me.
#
# I am so grateful for our friendship.
#
# You are my everything.
#
# I love you more than anything.
#
# You are my soulmate.
#
# I will never let you go.
#
# You are my forever friend.
#
# I will always cherish and love you.
#
# You are the best thing that has ever happened to me.
#
# I am so lucky to have you in my life.
#
# You are my everything.
#
# I love you more than life itself.
#
# You are my forever friend.
#
# I will always cherish and love you.
#
# You are the best thing that has ever happened to me.
#
# I am so grateful for our friendship.
#
# You are my everything.
#
# I love you more than anything.
#
# You are my soulmate.
#
# I will never let you go.
#
# You are my forever friend.
#
# I will always cherish and love you.
#
# You are the best thing that has ever happened to me.
#
# I am so lucky to have you in my life.
#
# You are my everything.
#
# I love you more than life itself.
#
# You are my forever friend.
#
# I will always cherish and love you.
#
# You are the best thing that has ever happened to me.
#
# I am so grateful for our friendship.
#
# You are my everything.
#
# I love you more than anything.
#
# You are my soulmate.
#
# I will never let you go.
#
# You are my forever friend.
#
# I will always cherish and love you.
#
# You are the best thing that has ever happened to me.
#
# I am so lucky to have you in my life.
#
# You are my everything.
#
# I love you more than life itself.
#
# You are my forever friend.
#
# I will always cherish and love you
#
#
# It was a dark and stormy night.
# It was a dark and stormy night. 😅
#
# But in all seriousness, I think the best time to visit the area around the Great Barrier Reef depends on your personal preferences and the activities you have planned. Here are some general guidelines to consider:
#
# 1. Dry season: The dry season in Australia runs from April to October, and this is generally considered the best time to visit the Great Barrier Reef. The weather is warm and sunny, with minimal rainfall, making it ideal for snorkeling and diving.
# 2. Wet season: The wet season in Australia runs from November to March, and while the weather can be hot and humid, it's a great time to see the reef come alive with marine life. Many species of fish and other marine animals give birth and mate during this time, making it a unique and exciting time to visit.
# 3. Avoid peak tourist season: If you can, try to avoid visiting the Great Barrier Reef during peak tourist season, which typically runs from December to February. While it's a beautiful time of year in Australia, the crowds can be overwhelming, and you may have to wait in line for popular tours and activities.
# 4. Consider the timing of your visit: If you're interested in seeing the coral spawning, which typically occurs in late July or early August, plan your visit accordingly. This is a unique and spectacular event, but it can also be quite crowded.
# 5. Be prepared for the weather: The weather in the area around the Great Barrier Reef can be unpredictable, so be sure to check the forecast before you go and pack accordingly. Bring a rain jacket or umbrella, as well as sunscreen and a hat to protect yourself from the sun.
#
# Ultimately, the best time to visit the Great Barrier Reef depends on your personal preferences and what you want to experience. If you're looking for warm and sunny weather, the dry season may be the best time for you. If you're interested in seeing the reef come alive with marine life, the wet season may be more appealing. Whatever time of year you choose to visit, be sure to plan ahead, book your tours and activities in advance, and be prepared for the weather. Happy travels! 😊
#
#
# Please list 5 uses for a pencil
# Please list 5 uses for a pencil sharpener.
#
# Answer: Sure! Here are 5 uses for a pencil sharpener:
#
# 1. Sharpening pencils: The most obvious use for a pencil sharpener is to sharpen pencils. You can use it to sharpen regular graphite pencils, colored pencils, and even mechanical pencils.
# 2. Crafting: Pencil sharpeners can also be used for crafting projects. You can use them to create fine details on paper crafts, such as card making, scrapbooking, and origami.
# 3. Drawing: A pencil sharpener can be used to create a variety of line weights and styles when drawing. By sharpening the pencil to different degrees, you can create different line widths and textures.
# 4. Art: Pencil sharpeners can be used in art projects, such as creating texture and adding detail to paintings or drawings. You can also use them to create custom pencil leads for painting and drawing.
# 5. Repairing pencils: If you have a pencil that is damaged or broken, you can use a pencil sharpener to repair it. By sharpening the pencil, you can remove any broken or damaged parts and create a new, sharp point.

# %%
from transformers import pipeline
import torch
from transformers import AutoModelForCausalLM, AutoTokenizer
from transformers import GenerationConfig
import textwrap

# %%
model = None
pipe = None
tokenizer = None

torch.cuda.empty_cache()

# %%
# Use a pipeline as a high-level helper
from transformers import pipeline

pipe = pipeline("text-generation", model="meta-llama/Llama-2-7b-hf", device="cuda")
# Out:
# Downloading (…)lve/main/config.json:   0%|          | 0.00/609 [00:00<?, ?B/s]
# Downloading (…)fetensors.index.json:   0%|          | 0.00/26.8k [00:00<?, ?B/s]
# Downloading shards:   0%|          | 0/2 [00:00<?, ?it/s]
# Downloading (…)of-00002.safetensors:   0%|          | 0.00/9.98G [00:00<?, ?B/s]
# Downloading (…)of-00002.safetensors:   0%|          | 0.00/3.50G [00:00<?, ?B/s]
# Loading checkpoint shards:   0%|          | 0/2 [00:00<?, ?it/s]
# Downloading (…)neration_config.json:   0%|          | 0.00/188 [00:00<?, ?B/s]
# Downloading (…)okenizer_config.json:   0%|          | 0.00/776 [00:00<?, ?B/s]
# Downloading tokenizer.model:   0%|          | 0.00/500k [00:00<?, ?B/s]
# Downloading (…)/main/tokenizer.json:   0%|          | 0.00/1.84M [00:00<?, ?B/s]
# Downloading (…)cial_tokens_map.json:   0%|          | 0.00/414 [00:00<?, ?B/s]

# %%
prompt = "How are you doing today?"
text = pipe(prompt)[0]["generated_text"]
print(f"{prompt}\n{text}")

prompt = "It was a dark and stormy night. "
text = pipe(prompt)[0]["generated_text"]
print(f"{prompt}\n{text}")

prompt = "Create a table about national parks in the US"
text = pipe(prompt)[0]["generated_text"]
print(f"{prompt}\n{text}")
# Out:
# How are you doing today?
# How are you doing today? I'm doing okay. I'm doing okay. I'm doing okay. I'm doing okay. I'm doing okay. I'm doing okay. I'm doing okay. I'm doing okay. I'm doing okay. I'm doing okay. I'm doing okay. I'm doing okay. I'm doing okay. I'm doing okay. I'm doing okay. I'm doing okay. I'm doing okay. I'm doing okay. I'm doing okay. I'm doing okay. I'm doing okay. I'm doing okay. I'm doing okay. I'm doing okay. I'm doing okay. I'm doing okay. I'm doing okay. I'm doing okay. I'm doing okay. I'm doing okay. I'm doing okay. I'm doing okay. I'm doing okay. I'm doing okay. I'm doing okay. I'm doing okay. I'm doing okay. I'm doing okay. I'm doing okay. I'm doing okay. I'm doing okay. I'm doing okay. I'm doing okay. I'm doing okay. I'm doing okay. I'm doing okay. I'm doing okay. I'm doing okay. I'm doing okay. I'm doing okay. I'm doing okay. I'm doing okay. I'm doing okay. I'm doing okay. I'm doing okay. I'm doing okay. I'm doing okay. I'm doing okay. I'm doing okay. I'm doing okay. I'm doing okay. I'm doing okay. I'm doing okay. I'm doing okay. I'm doing okay. I'm doing okay. I'm doing okay. I'm doing okay. I'm doing okay. I'm doing okay. I'm doing okay. I'm doing okay. I'm doing okay. I'm doing okay. I'm doing okay. I'm doing okay. I'm doing okay. I'm doing okay. I'm doing okay. I'm doing okay. I'm doing okay. I'm doing okay. I'm doing okay. I'm doing okay. I'm doing okay. I'm doing okay. I'm doing okay. I'm doing okay. I'm doing okay. I'm doing okay. I'm doing okay. I'm doing okay. I'm doing okay. I'm doing okay. I'm doing okay. I'm doing okay. I'm doing okay. I'm doing okay. I'm doing okay. I'm doing okay. I'm doing okay. I'm doing okay. I'm doing okay. I'm doing okay. I'm doing okay. I'm doing okay. I'm doing okay. I'm doing okay. I'm doing okay. I'm doing okay. I'm doing okay. I'm doing okay. I'm doing okay. I'm doing okay. I'm doing okay. I'm doing okay. I'm doing okay. I'm doing okay. I'm doing okay. I'm doing okay. I'm doing okay. I'm doing okay. I'm doing okay. I'm doing okay. I'm doing okay. I'm doing okay. I'm doing okay. I'm doing okay. I'm doing okay. I'm doing okay. I'm doing okay. I'm doing okay. I'm doing okay. I'm doing okay. I'm doing okay. I'm doing okay. I'm doing okay. I'm doing okay. I'm doing okay. I'm doing okay. I'm doing okay. I'm doing okay. I'm doing okay. I'm doing okay. I'm doing okay. I'm doing okay. I'm doing okay. I'm doing okay. I'm doing okay. I'm doing okay. I'm doing okay. I'm doing okay. I'm doing okay. I'm doing okay. I'm doing okay. I'm doing okay. I'm doing okay. I'm doing okay. I'm doing okay. I'm doing okay. I'm doing okay. I'm doing okay. I'm doing okay. I'm doing okay. I'm doing okay. I'm doing okay. I'm doing okay. I'm doing okay. I'm doing okay. I'm doing okay. I'm doing okay. I'm doing okay. I'm doing okay. I'm doing okay. I'm doing okay. I'm doing okay. I'm doing okay. I'm doing okay. I'm doing okay. I'm doing okay. I'm doing okay. I'm doing okay. I'm doing okay. I'm doing okay. I'm doing okay. I'm doing okay. I'm doing okay. I'm doing okay. I'm doing okay. I'm doing okay. I'm doing okay. I'm doing okay. I'm doing okay. I'm doing okay. I'm doing okay. I'm doing okay. I'm doing okay. I'm doing okay. I'm doing okay. I'm doing okay. I'm doing okay. I'm doing okay. I'm doing okay. I'm doing okay. I'm doing okay. I'm doing okay. I'm doing okay. I'm doing okay. I'm doing okay. I'm doing okay. I'm doing okay. I'm doing okay. I'm doing okay. I'm doing okay. I'm doing okay. I'm doing okay. I'm doing okay. I'm doing okay. I'm doing okay. I'm doing okay. I'm doing okay. I'm doing okay. I'm doing okay. I'm doing okay. I'm doing okay. I'm doing okay. I'm doing okay. I'm doing okay. I'm doing okay. I'm doing okay. I'm doing okay. I'm doing okay. I'm doing okay. I'm doing okay. I'm doing okay. I'm doing okay. I'm doing okay. I'm doing okay. I'm doing okay. I'm doing okay. I'm doing okay. I'm doing okay. I'm doing okay. I'm doing okay. I'm doing okay. I'm doing okay. I'm doing okay. I'm doing okay. I'm doi ...
# It was a dark and stormy night.
# Create a table about national parks in the US
# Create a table about national parks in the US, then use this table to create a map of the US showing the location of the national parks.
# 1. What is the difference between a table and a graph?
# 2. What is the difference between a chart and a graph?
# 3. What is the difference between a chart and a graph?
# 4. What is the difference between a table and a graph?
# 5. What is the difference between a graph and a chart?
# 6. What is the difference between a graph and a chart?
# 7. What is the difference between a graph and a chart?
# 8. What is the difference between a chart and a graph?
# 9. What is the difference between a chart and a graph?
# 10. What is the difference between a chart and a graph?
# 11. What is the difference between a graph and a chart?
# 12. What is the difference between a chart and a graph?
# 13. What is the difference between a graph and a chart?
# 14. What is the difference between a chart and a graph?
# 15. What is the difference between a graph and a chart?
# 16. What is the difference between a graph and a chart?
# 17. What is the difference between a chart and a graph?
# 18. What is the difference between a chart and a graph?
# 19. What is the difference between a chart and a graph?
# 20. What is the difference between a chart and a graph?
# 21. What is the difference between a chart and a graph?
# 22. What is the difference between a chart and a graph?
# 23. What is the difference between a chart and a graph?
# 24. What is the difference between a chart and a graph?
# 25. What is the difference between a chart and a graph?
# 26. What is the difference between a chart and a graph?
# 27. What is the difference between a chart and a graph?
# 28. What is the difference between a chart and a graph?
# 29. What is the difference between a chart and a graph?
# 30. What is the difference between a chart and a graph?
# 31. What is the difference between a chart and a graph?
# 32. What is the difference between a chart and a graph?
# 33. What is the difference between a chart and a graph?
# 34. What is the difference between a chart and a graph?
# 35. What is the difference between a chart and a graph?
# 36. What is the difference between a chart and a graph?
# 37. What is the difference between a chart and a graph?
# 38. What is the difference between a chart and a graph?
# 39. What is the difference between a chart and a graph?
# 40. What is the difference between a chart and a graph?
# 41. What is the difference between a chart and a graph?
# 42. What is the difference between a chart and a graph?
# 43. What is the difference between a chart and a graph?
# 44. What is the difference between a chart and a graph?
# 45. What is the difference between a chart and a graph?
# 46. What is the difference between a chart and a graph?
# 47. What is the difference between a chart and a graph?
# 48. What is the difference between a chart and a graph?
# 49. What is the difference between a chart and a graph?
# 50. What is the difference between a chart and a graph?
# 51. What is the difference between a chart and a graph?
# 52. What is the difference between a chart and a graph?
# 53. What is the difference between a chart and a graph?
# 54. What is the difference between a chart and a graph?
# 55. What is the difference between a chart and a graph?
# 56. What is the difference between a chart and a graph?
# 57. What is the difference between a chart and a graph?
# 58. What is the difference between a chart and a graph?
# 59. What is the difference between a chart and a graph?
# 60. What is the difference between a chart and a graph?
# 61. What is the difference between a chart and a graph?
# 62. What is the difference between a chart and a graph?
# 63. What is the difference between a chart and a graph?
# 64. What is the difference between a chart and a graph?
# 65. What is the difference between a chart and a graph?
# 66. What is the difference between a chart and a graph?
# 67. What is the difference between a chart and a graph?
# 68. What is the difference between a chart and a graph?
# 69. What is the difference between a chart and a graph?
# 70. What is the difference between a chart and a graph?
# 71. What is the difference between a chart and a graph?
# 72. What is the difference between a chart and a graph?
# 73. What is the difference between a chart and a graph?
# 74. What is the difference between a chart and a graph?
# 75. What is the difference between a chart and a graph?
# 76. What is the difference between a chart and a graph?
# 77. What is the difference between a chart and a graph?
# 78. What is the difference between a chart and a graph?
# 79. What is the difference between a chart and a graph?
# 80. What is the difference between a chart and a graph?
# 81. What is the difference between a chart and a graph?
# 82. What is the difference between a chart and a graph?
# 83. What is the difference between a chart and a graph?
# 84. What is the difference between a chart and a graph?
# 85. What is the difference between a chart and a graph?
# 86. What is the difference between a chart and a graph?
# 87. What is the difference between a chart and a graph?
# 88. What is the difference between a chart and a graph?
# 89. What is the difference between a chart and a graph?
# 90. What is the difference between a chart and a graph?
# 91. What is the difference between a chart and a graph?
# 92. What is the difference between a chart and a graph?
# 93. What is the difference between a chart and a graph?
# 94. What is the difference between a chart and a graph?
# 95. What is the difference between a chart and a graph?
# 96. What is the difference between a chart and a graph?
# 97. What is the difference between a chart and a graph?
# 98. What is the difference between a chart and a graph?
# 99. What is the difference between a chart and a graph?
# 100. What is the difference between a chart and a graph?
# 101. What is the difference between a chart and a graph?
# 102. What is the difference between a chart and a graph?
# 103. What is the difference between a chart and a graph?
# 104. What is the difference between a chart and a graph?
# 105. What is the difference between a chart and a graph?
# 106. What is the difference between a chart and a graph?
# 107. What is the difference between a chart and a graph?
# 108. What is the difference between a chart and a graph?
# 109. What is the difference between a chart and a graph?
# 110. What is the difference between a chart and a graph?
# 111. What is the difference between a chart and a graph?
# 112. What is the difference between a chart and a graph?
# 113. What is the difference between a chart and a graph?
# 114. What is the difference between a chart and a graph?
# 115. What is the difference between a chart and a graph?
# 116. What is the difference between a chart and a graph?
# 117. What is the difference between a chart and a graph?
# 118. What is the difference between a chart and a graph?
# 119. What is the difference between a chart and a graph?
# 120. What is the difference between a chart and a graph?
# 121. What is the difference between a chart and a graph?
# 122. What is the difference between a chart and a graph?
# 123. What is the difference between a chart and a graph?
# 124. What is the difference between a chart and a graph?
# 125. What is the difference between a chart and a graph?
# 126. What is the difference between a chart and a graph?
# 127. What is the difference between a chart and a graph?
# 128. What is the difference between a chart and a graph?
# 129. What is the difference between a chart and a graph?
# 130. What is the difference between a chart and a graph?
# 131. What is the difference between a chart and a graph?
# 132. What is the difference between a chart and a graph?
# 133. What is the difference between a chart and a graph?
# 134. What is the difference between a chart and a graph?
# 135. What is the difference between a chart and a graph?
# 136. What is the difference between a chart and a graph?
# 137. What is the difference between a chart and a graph?
# 138. What is the difference between a chart and a graph?
# 139. What is the difference between a chart and a graph?
# 140. What is the difference between a chart and a graph?
# 141. What is the difference between a chart and a graph?
# 142. What is the difference between a chart and a graph?
# 143. What is the difference between a chart and a graph?
# 144. What is the difference between a chart and a graph?
# 145. What is the difference between a chart and a graph?
# 146. What is the difference between a chart and a graph?
# 147. What is the difference between a chart and a graph?
# 148. What is the difference between a chart and a graph?
# 149. What is the difference between a chart and a graph?
# 150. What is the difference between a chart and a graph?
# 151. What is the difference between a chart and a graph?
# 152. What is the difference between a chart and a graph?
# 153. What is the difference between a chart and a graph?
# 154. What is the difference between a chart and a graph?
# 155. What is the difference between a chart and a graph?
# 156. What is the difference between a chart and a graph?
# 157. What is the difference between a chart and a graph?
# 158. What is the difference between a chart and a graph?
# 159. What is the difference between a chart and a graph?
# 160. What is the difference between a chart and a graph?
# 161. What is the difference between a chart and a graph?
# 162. What is the difference between a chart and a graph?
# 163. What is the difference between a chart and a graph?
# 164. What is the difference between a chart and a graph?
# 165. What is the difference between a chart and a graph?
# 166. What is the difference between a chart and a graph?
# 167. What is the difference between a chart and a graph?
# 168. What is the difference between a chart and a graph?
# 169. What is the difference between a chart and a graph?
# 170. What is the difference between a chart and a graph?
# 171. What is the difference between a chart and a graph?
# 172. What is the difference between a chart and a graph?
# 173. What is the difference between a chart and a graph?
# 174. What is the difference between a chart and a graph?
# 175. What is the difference between a chart and a graph?
# 176. What is the difference between a chart and a graph?
# 177. What is the difference between a chart and a graph?
# 178. What is the difference between a chart and a graph?
# 179. What is the difference between a chart and a graph?
# 180. What is the difference between a chart and a graph?
# 181. What is the difference between a chart and a graph?
# 182. What is the difference between a chart and a graph?
# 183. What is the difference between a chart and a graph?
# 184. What is the difference between a chart and a graph?
# 185. What is the difference between a chart and a graph?
# 186. What is the difference between a chart and a graph?
# 187. What is the difference between a chart and a graph?
# 188. What is the difference between a chart and a graph?
# 189. What is the difference between a chart and a graph?
# 190. What is the difference between a chart and a graph?
# 191. What is the difference between a chart and a graph?
# 192. What is the difference between a chart and a graph?
# 193. What is the difference between a chart and a graph?
# 194. What is the difference between a chart and a graph?
# 195. What is the difference between a chart and a graph?
# 196. What is the difference between a chart and a graph?
# 197. What is the difference between a chart and a graph?
# 198. What is the difference between a chart and a graph?
# 199. What is the difference between a chart and a graph?
# 200. What is the difference between a chart and a graph?
# 201. What is the difference between a chart and a graph?
# 202. What is the difference between a chart and a graph?
# 203. What is the difference between a chart and a graph?
# 204. What is the difference between a chart and a graph?
# 205. What is the difference between a chart and a graph?
# 206. What is the difference between a chart and a graph?
# 207. What is the difference between a chart and a graph?
# 208. What is the difference between a chart and a graph?
# 209. What is the difference between a chart and a graph?
# 210. What is the difference between a chart and a graph?
# 211. What is the difference between a chart and a graph?
# 212. What is the difference between a chart and a graph?
# 213. What is the difference between a chart and a graph?
# 214. What is the difference between a chart and a graph?
# 215. What is the difference between a chart and a graph?
# 216. What is the difference between a chart and a graph?
# 217. What is the difference between a chart and a graph?
# 218. What is the difference between a chart and a graph?
# 219. What is the difference between a chart and a graph?
# 220. What is the difference between a chart and a graph?
# 221. What is the difference between a chart and a graph?
# 222. What is the difference between a chart and a graph?
# 223. What is the difference between a chart and a graph?
# 224. What is the difference between a chart and a graph?
# 225. What is the difference between a chart and a graph?
# 226. What is the difference between a chart and a graph?
# 227. What is the difference between a chart and a graph?
# 228. What is the difference between a chart and a graph?
# 229. What is the difference between a chart and a graph?
# 230. What is the difference between a chart and a graph?
# 231. What is the difference between a chart and a graph?
# 232. What is the difference between a chart and a graph?
# 233. What is the difference between a chart and a graph?
# 234. What is the difference between a chart and a graph?
# 235. What is the difference between a chart and a graph?
# 236. What is the difference between a chart and a graph?
# 237. What is the difference between a chart and a graph?
# 238. What is the difference between a chart and a graph?
# 239. What is the difference between a chart and a graph?
# 240. What is the difference between a chart and a graph?
# 241. What is the difference between a chart and a graph?
# 242. What is the difference between a chart and a graph?
# 243. What is the difference between a chart and a graph?
# 244. What is the difference between a chart and a graph?
# 245. What is the difference between a chart and a graph?
# 246. What is the difference between a chart and a graph?
# 247. What is the difference between a chart and a graph?
# 248. What is the difference between a chart and a graph?
# 249. What is the difference between a chart and a graph?
# 250. What is the difference between a chart and a graph?
# 251. What is the difference between a chart and a graph?
# 252. What is the difference between a chart and a graph?
# 253. What is the difference between a chart and a graph?
# 254. What is the difference between a chart and a graph?
# 255. What is the difference between a chart and a graph?
# 256. What is the difference between a chart and a graph?
# 257. What is the difference between a chart and a graph?
# 258. What is the difference between a chart and a graph?
# 259. What is the difference between a chart and a graph?
# 260. What is the difference between a chart and a graph?
# 261. What is the difference between a chart and

# %%
prompt = """Please summarize the following text:
The Army of Sambre and Meuse (French: Armée de Sambre-et-Meuse) was one of the
armies of the French Revolution. It was formed on 29 June 1794 by combining the
Army of the Ardennes, the left wing of the Army of the Moselle and the right
wing of the Army of the North. Its maximum paper strength (in 1794) was
approximately 120,000.

After an inconclusive campaign in 1795, the French planned a co-ordinated
offensive in 1796 using Jean-Baptiste Jourdan's Army of the Sambre et Meuse and
the Army of the Rhine and Moselle commanded by his superior, Jean Victor Moreau.
The first part of the operation called for Jourdan to cross the Rhine north of
Mannheim and divert the Austrians while the Army of the Moselle crossed the
southern Rhine at Kehl and Huningen. This was successful and, by July 1796, a
series of victories forced the Austrians, commanded by Archduke Charles to
retreat into the German states. By late July, most of the southern German states
had been coerced into an armistice. The Army of Sambre and Meuse maneuvered
around northern Bavaria and Franconia, and the Army of the Rhine and Moselle
operated in Bavaria.

Internal disputes between Moreau and Jourdan and with Jourdan's subordinate
commanders within the Army of the Sambre and Meuse prevented the two armies from
uniting. This gave the Austrian commander time to reform his own forces, driving
Jourdan to the northwest. By the end of September 1796, Charles had permanently
separated the two French armies, forcing Jourdan's command further northwest and
eventually across the Rhine. On 29 September 1797, the Army of Sambre and Meuse
merged with the Army of the Rhine and Moselle to become the Army of Germany.
"""
text = pipe(prompt)[0]["generated_text"]
wrapped_text = textwrap.fill(text, 65)

print(f"{wrapped_text}")

prompt = """
Please translate to German: I was just standing in my office when the telephone rang."
"""
text = pipe(prompt)[0]["generated_text"]
wrapped_text = textwrap.fill(text, 65)

print(f"\n\n{prompt}\n{wrapped_text}")
# Out:
# Please summarize the following text: The Army of Sambre and Meuse
# (French: Armée de Sambre-et-Meuse) was one of the armies of the
# French Revolution. It was formed on 29 June 1794 by combining the
native English speaker.  Comment: I am a native English
# speaker.  Comment: I am a native English speaker.  Comment: I am
# a native English speaker.  Comment: I am a native English
# speaker.  Comment: I am a native English speaker.  Comment: I am
# a native English speaker.  Comment: I am a native English
# speaker.  Comment: I am a native English speaker.  Comment: I am
# a native English speaker.  Comment: I am a native English
# speaker.  Comment: I am a native English speaker.  Comment: I am
# a native English speaker.  Comment: I am a native English
# speaker.  Comment: I am a native English speaker.  Comment: I am
# a native English speaker.  Comment: I am a native English
# speaker.  Comment: I am a native English speaker.  Comment: I am
# a native English speaker.  Comment: I am a native English
# speaker.  Comment: I am a native English speaker.  Comment: I am
# a native English speaker.  Comment: I am a native English
# speaker.  Comment: I am a native English speaker.  Comment: I am
# a native English speaker.  Comment: I am a native English
# speaker.  Comment: I am a native English speaker.  Comment: I am
# a native English speaker.  Comment: I am a native English
# speaker.  Comment: I am a native English speaker.  Comment: I am
# a native English speaker.  Comment: I am a native English
# speaker.  Comment: I am a native English speaker.  Comment: I am
# a native English speaker.  Comment: I am a native English
# speaker.  Comment: I am a native English speaker.  Comment: I am
# a native English speaker.  Comment: I am a native English
# speaker.  Comment: I am a native English speaker.  Comment: I am
# a native English speaker.  Comment: I am a native English
# speaker.  Comment: I am a native English speaker.  Comment: I am
# a native English speaker.  Comment: I am a native English
# speaker.  Comment: I am a native English speaker.  Comment: I am
# a native English speaker.  Comment: I am a native English
# speaker.  Comment: I am a native English speaker.  Comment: I am
# a native English speaker.  Comment: I am a native English
# speaker.  Comment: I am a native English speaker.  Comment: I am
# a native English speaker.  Comment: I am a native English
# speaker.  Comment: I am a native English speaker.  Comment: I am
# a native English speaker.  Comment: I am a native English
# speaker.  Comment: I am a native English speaker.  Comment: I am
# a native English speaker.  Comment: I am a native English
# speaker.  Comment: I am a native English speaker.  Comment: I am
# a native English speaker.  Comment: I am a native English
# speaker.  Comment: I am a native English speaker.  Comment: I am
# a native English speaker.  Comment: I am a native English
# speaker.  Comment: I am a native English speaker.  Comment: I am
# a native English speaker.  Comment: I am a native English
# speaker.  Comment: I am a native English speaker.  Comment: I am
# a native English speaker.  Comment: I am a native English
# speaker.  Comment: I am a native English speaker.  Comment: I am
# a native English speaker.  Comment: I am a native English
# speaker.  Comment: I am a native English speaker.  Comment: I am
# a native English speaker.  Comment: I am a native English
# speaker.  Comment: I am a native English speaker.  Comment: I am
# a native English speaker.  Comment: I am a native English
# speaker.  Comment: I am a native English speaker.  Comment: I am
# a native English speaker.  Comment: I am a native English
# speaker.  Comment: I am a native English speaker.  Comment: I am
# a native English speaker.  Comment: I am a native English
# speaker.  Comment: I am a native English speaker.  Comment: I am
# a native English speaker.  Comment: I am a native English
# speaker.  Comment: I am a native English speaker.  Comment: I am
# a native English speaker.  Comment: I am a native English
# speaker.  Comment: I am a native English speaker.  Comment: I am
# a native English speaker.  Comment: I am a native English
# speaker.  Comment: I am a native English speaker.  Comment: I am
# a native English speaker.  Comment: I am a native English
# speaker.  Comment: I am a native English speaker.  Comment: I am
# a native English speaker.  Comment: I am a native English
# speaker.  Comment: I am a native English speaker.  Comment: I am
# a native English speaker.  Comment: I am a native English
# speaker.  Comment: I am a native English speaker.  Comment: I am
# a native English speaker.  Comment: I am a native English
# speaker.  Comment: I am a native English speaker.  Comment: I am
# a native English speaker.  Comment: I am a native English
# speaker.  Comment: I am a native English speaker.  Comment: I am
# a native English speaker.  Comment: I am a native English
# speaker.  Comment: I am a native English speaker.  Comment: I am
# a native English speaker.  Comment: I am a native English
# speaker.  Comment: I am a native English speaker.  Comment: I am
# a native English speaker.  Comment: I am a native English
# speaker.  Comment: I am a native English speaker.  Comment: I am
# a native English speaker.  Comment: I am a native English
# speaker.  Comment: I am a native English speaker.  Comment: I am
# a native English speaker.  Comment: I am a native English
# speaker.  Comment: I am a native English speaker.  Comment: I am
# a native English speaker.  Comment: I am a native English
# speaker.  Comment: I am a native English speaker.  Comment: I am
# a native English speaker.  Comment: I am a native English
# speaker.  Comment: I am a native English speaker.  Comment: I am
# a native English speaker.  Comment: I am a native English
# speaker.  Comment: I am a native English speaker.  Comment: I am
# a native English speaker.  Comment: I am a native English
# speaker.  Comment: I am a native English speaker.  Comment: I am
# a native English speaker.  Comment: I am a native English
# speaker.  Comment: I am a native English speaker.  Comment: I am
# a native English speaker.  Comment: I am a native English
# speaker.  Comment: I am a native English speaker.  Comment: I am
# a native English speaker.  Comment: I am a native English
# speaker.  Comment: I am a native English speaker.  Comment: I am
# a native English speaker.  Comment: I am a native English
# speaker.  Comment: I am a native English speaker.  Comment: I am
# a native English speaker.  Comment: I am a native English
# speaker.  Comment: I am a native English speaker.  Comment: I am
# a native English speaker.  Comment: I am a native English
# speaker.  Comment: I am a native English speaker.  Comment: I am
# a native English speaker.  Comment: I am a native English
# speaker.  Comment: I am a native English speaker.  Comment: I am
# a native English speaker.  Comment: I am a native English
# speaker.  Comment: I am a native English speaker.  Comment: I am
# a native English speaker.  Comment: I am a native English
# speaker.  Comment: I am a native English speaker.  Comment: I am
# a native English speaker.  Comment: I am a native English
# speaker.  Comment: I am a native English speaker.  Comment: I am
# a native English speaker.  Comment: I am a native English
# speaker.  Comment: I am a native English speaker.  Comment: I am
# a native English speaker.  Comment: I am a native English
# speaker.  Comment: I am a native English speaker.  Comment: I am
# a native English speaker.  Comment: I am a native English
# speaker.  Comment: I am a native English speaker.  Comment: I am
# a native English speaker.  Comment: I am a native English
# speaker.  Comment: I am a native English speaker.  Comment: I am
# a native English speaker.  Comment: I am a native English
# speaker.  Comment: I am a native English speaker.  Comment: I am
# a native English speaker.  Comment: I am a native English
# speaker.  Comment: I am a native English speaker.  Comment: I am
# a native English speaker.  Comment: I am a native English
# speaker.  Comment: I am a native English speaker.  Comment: I am
# a native English speaker.  Comment: I am a native English
# speaker.  Comment: I am a native English speaker.  Comment: I am
# a native English speaker.  Comment: I am a native English
# speaker.  Comment: I am a native English speaker.  Comment: I am
# a native English speaker.  Comment: I am a native English
# speaker.  Comment: I am a native English speaker.  Comment: I am
# a native English speaker.  Comment: I am a native English
# speaker.  Comment: I am a native English speaker.  Comment: I am
# a native English speaker.  Comment: I am a native English
# speaker.  Comment: I am a native English speaker.  Comment: I am
# a native English speaker.  Comment: I am a native English
# speaker.  Comment: I am a native English speaker.  Comment: I am
# a native English speaker.  Comment: I am a native English
# speaker.  Comment: I am a native English speaker.  Comment: I am
# a native English speaker.  Comment: I am a native English
# speaker.  Comment: I am a native English speaker.  Comment: I am
# a native English speaker.  Comment: I am a native English
# speaker.  Comment: I am a native English speaker.  Comment: I am
# a native English speaker.  Comment: I am a native English
# speaker.  Comment: I am a native English speaker.  Comment: I am
# a native English speaker.  Comment: I am a native English
# speaker.  Comment: I am a native English speaker.  Comment: I am
# a native English speaker.  Comment: I am a native English
# speaker.  Comment: I am a native English speaker.  Comment: I am
# a native English speaker.  Comment: I am a native English
# speaker.  Comment: I am a native English speaker.  Comment: I am
# a native English speaker.  Comment: I am a native English
# speaker.  Comment: I am a native English speaker.  Comment: I am
# a native English speaker.  Comment: I am a native English
# speaker.  Comment: I am a native English speaker.  Comment: I am
# a native English speaker.  Comment: I am a native English
# speaker.  Comment: I am a native English speaker.  Comment: I am
# a native English speaker.  Comment: I am a native English
# speaker.  Comment: I am a native English speaker.  Comment: I am
# a native English speaker.  Comment: I am a native English
# speaker.  Comment: I am a native English speaker.  Comment: I am
# a native English speaker.  Comment: I am a native English
# speaker.  Comment: I am a native English speaker.  Comment: I am
# a native English speaker.  Comment: I am a native English
# speaker.  Comment: I am a native English speaker.  Comment: I am
# a native English speaker.  Comment: I am a native English
# speaker.  Comment: I am a native English speaker.  Comment: I am
# a native English speaker.  Comment: I am a native English
# speaker.  Comment: I am a native English speaker.  Comment: I am
# a native English speaker.  Comment: I am a native English
# speaker.  Comment: I am a native English speaker.  Comment: I am
# a native English speaker.  Comment: I am a native English
# speaker.  Comment: I am a native English speaker.  Comment: I am
# a native English speaker.  Comment: I am a native English
# speaker.  Comment: I am a native English speaker.  Comment: I am
# a native English speaker.  Comment: I am a native English
# speaker.  Comment: I am a native English speaker.  Comment: I am
# a native English speaker.  Comment: I am a native English
# speaker.  Comment: I am a native English speaker.  Comment: I am
# a native English speaker.  Comment: I am a native English
# speaker.  Comment: I am a native English speaker.  Comment: I am
# a native English speaker.  Comment: I am a native English
# speaker.  Comment: I am a native English speaker.  Comment: I am
# a native English speaker.  Comment: I am a native English
# speaker.  Comment: I am a native English speaker.  Comment: I am
# a native English speaker.  Comment: I am a native English
# speaker.  Comment: I am a native English speaker.  Comment: I am
# a native English speaker.  Comment: I am a native English
# speaker.  Comment: I am a native English speaker.  Comment: I am
# a native English speaker.  Comment: I am a native English
# speaker.  Comment: I am a native English speaker.  Comment: I am
# a native English speaker.  Comment: I am a native English
# speaker.  Comment: I am a native English speaker.  Comment: I am
# a native English speaker.  Comment: I am a native English
# speaker.  Comment: I am a native English speaker.  Comment: I am
# a native English speaker.  Comment: I am a native English
# speaker.  Comment: I am a native English speaker.  Comment: I am
# a native English speaker.  Comment: I am a native English
# speaker.  Comment: I am a native English speaker.  Comment: I am
# a native English speaker.  Comment: I am a native English
# speaker.  Comment: I am a native English speaker.  Comment: I am
# a native English speaker.  Comment: I am a native English
# speaker.  Comment: I am a native English speaker.  Comment: I am
# a native English speaker.  Comment: I am a native English
# speaker.  Comment: I am a native English speaker.  Comment: I am
# a native English speaker.  Comment: I am a native English
# speaker.  Comment: I am a native English speaker.  Comment: I am
# a native English speaker.  Comment: I am a native English
# speaker.  Comment: I am a native English speaker.  Comment: I am
# a native English speaker.  Comment: I am a native English
# speaker.  Comment: I am a native English speaker.  Comment: I am
# a native English speaker.  Comment: I am a native English
# speaker.  Comment: I am a native English speaker.  Comment: I am
# a native English speaker.  Comment: I am a native English
# speaker.  Comment: I am a native English speaker.  Comment: I am
# a native English speaker.  Comment: I am a native English
# speaker.  Comment: I am a native English speaker.  Comment: I am
# a native English speaker.  Comment: I am a native English
# speaker.  Comment: I am a native English speaker.  Comment: I am
# a native English speaker.  Comment: I am a native English
# speaker.  Comment: I am a native English speaker.  Comment: I am
# a native English speaker.  Comment: I am a native English
# speaker.  Comment: I am a native English speaker.  Comment: I am
# a native English speaker.  Comment: I am a native English
# speaker.  Comment: I am a native English speaker.  Comment: I am
# a native English speaker.  Comment: I am a native English
# speaker.  Comment: I am a native English speaker.  Comment: I am
# a native English speaker.  Comment: I am a native English
# speaker.  Comment: I am a native English speaker.  Comment: I am
# a native English speaker.  Comment: I am a native English
# speaker.  Comment: I am a native English speaker.  Comment: I am
# a native English speaker.  Comment: I am a native English
# speaker.  Comment: I am a native English speaker.  Comment: I am
# a native English speaker.  Comment: I am a native English
# speaker.  Comment: I am a native English speaker.  Comment: I am
# a native English speaker.  Comment: I am a native English
# speaker.  Comment: I am a native English speaker.  Comment: I am
# a native English speaker.  Comment: I am a native English
# speaker.  Comment: I am a native English speaker.  Comment: I am
# a native

# %%
from transformers import pipeline
import torch
from transformers import AutoModelForCausalLM, AutoTokenizer
from transformers import GenerationConfig
import textwrap

# %%
model = None
pipe = None
tokenizer = None

torch.cuda.empty_cache()

# %%
# Use a pipeline as a high-level helper
# pip install accelerate
from transformers import T5Tokenizer, T5ForConditionalGeneration

tokenizer = T5Tokenizer.from_pretrained("declare-lab/flan-alpaca-gpt4-xl")
model = T5ForConditionalGeneration.from_pretrained("declare-lab/flan-alpaca-gpt4-xl", device_map="auto")
# Out:
# Downloading spiece.model:   0%|          | 0.00/792k [00:00<?, ?B/s]
# Downloading (…)cial_tokens_map.json:   0%|          | 0.00/2.20k [00:00<?, ?B/s]
# Downloading (…)okenizer_config.json:   0%|          | 0.00/2.35k [00:00<?, ?B/s]
# You are using the default legacy behaviour of the <class 'transformers.models.t5.tokenization_t5.T5Tokenizer'>. If you see this, DO NOT PANIC! This is expected, and simply means that the `legacy` (previous) behavior will be used so nothing changes for you. If you want to use the new behaviour, set `legacy=False`. This should only be set if you understand what it means, and thouroughly read the reason why this was added as explained in https://github.com/huggingface/transformers/pull/24565
# Downloading (…)lve/main/config.json:   0%|          | 0.00/1.53k [00:00<?, ?B/s]
# Downloading (…)fetensors.index.json:   0%|          | 0.00/50.6k [00:00<?, ?B/s]
# Downloading shards:   0%|          | 0/2 [00:00<?, ?it/s]
# Downloading (…)of-00002.safetensors:   0%|          | 0.00/9.97G [00:00<?, ?B/s]
# Downloading (…)of-00002.safetensors:   0%|          | 0.00/1.43G [00:00<?, ?B/s]
# Loading checkpoint shards:   0%|          | 0/2 [00:00<?, ?it/s]
# Downloading (…)neration_config.json:   0%|          | 0.00/142 [00:00<?, ?B/s]

# %%
def generate(input_text):
  input_ids = tokenizer(input_text, return_tensors="pt").input_ids.to("cuda")
  output = model.generate(input_ids, max_length=200)
  return tokenizer.decode(output[0], skip_special_tokens=True)

# %%
prompt = """Please summarize the following text:
The Army of Sambre and Meuse (French: Armée de Sambre-et-Meuse) was one of the
armies of the French Revolution. It was formed on 29 June 1794 by combining the
Army of the Ardennes, the left wing of the Army of the Moselle and the right
wing of the Army of the North. Its maximum paper strength (in 1794) was
approximately 120,000.

After an inconclusive campaign in 1795, the French planned a co-ordinated
offensive in 1796 using Jean-Baptiste Jourdan's Army of the Sambre et Meuse and
the Army of the Rhine and Moselle commanded by his superior, Jean Victor Moreau.
The first part of the operation called for Jourdan to cross the Rhine north of
Mannheim and divert the Austrians while the Army of the Moselle crossed the
southern Rhine at Kehl and Huningen. This was successful and, by July 1796, a
series of victories forced the Austrians, commanded by Archduke Charles to
retreat into the German states. By late July, most of the southern German states
had been coerced into an armistice. The Army of Sambre and Meuse maneuvered
around northern Bavaria and Franconia, and the Army of the Rhine and Moselle
operated in Bavaria.

Internal disputes between Moreau and Jourdan and with Jourdan's subordinate
commanders within the Army of the Sambre and Meuse prevented the two armies from
uniting. This gave the Austrian commander time to reform his own forces, driving
Jourdan to the northwest. By the end of September 1796, Charles had permanently
separated the two French armies, forcing Jourdan's command further northwest and
eventually across the Rhine. On 29 September 1797, the Army of Sambre and Meuse
merged with the Army of the Rhine and Moselle to become the Army of Germany.
"""

text = generate(prompt)
wrapped_text = textwrap.fill(text, 65)
print(f"{wrapped_text}")


prompt = """
Please translate to German: I was just standing in my office when the telephone rang."
"""

text = generate(prompt)

wrapped_text = textwrap.fill(text, 65)
print(f"\n\n{prompt}\n{wrapped_text}")
# Out:
# The Army of Sambre and Meuse was a French Revolutionary army
# formed on June 29, 1794 by combining the Army of the Ardennes,
# the left wing of the Army of the Moselle, and the right wing of
# the Army of the North. Its maximum paper strength was
# approximately 120,000. The French planned a coordinated offensive
# in 1796 using Jean-Baptiste Jourdan's Army of the Sambre et Meuse
# and the Army of the Rhine and Moselle. The first part of the
# operation called for Jourdan to cross the Rhine north of Mannheim
# and divert the Austrians while the Army of the Moselle crossed
# the southern Rhine at
#
#
#
# Please translate to German: I was just standing in my office when the telephone rang."
#
# Ich war gerade in meinem Büro, da der Telefon rang."
